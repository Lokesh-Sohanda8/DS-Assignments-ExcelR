# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
import pandas as pd
import pickle
from sklearn import set_config
set_config(display='diagram')

# %%
# Load train data
train_data = pd.read_csv('Titanic_train.csv')
X_train = train_data.drop(['Name', 'Pclass', 'Ticket', 'Parch', 'Cabin', 'Survived'], axis=1)  # Replace 'target' with the actual target column name
y_train = train_data['Survived']

# Load test data
test_data = pd.read_csv('Titanic_test.csv')
X_test = test_data.drop(['Parch', 'Name', 'Pclass', 'Ticket', 'Cabin'], axis=1)  # Replace 'target' with the actual target column name (if applicable)

# %%
X_train
# Out:
#      PassengerId     Sex   Age  SibSp     Fare Embarked
# 0              1    male  22.0      1   7.2500        S
# 1              2  female  38.0      1  71.2833        C
# 2              3  female  26.0      0   7.9250        S
# 3              4  female  35.0      1  53.1000        S
# 4              5    male  35.0      0   8.0500        S
# ..           ...     ...   ...    ...      ...      ...
# 886          887    male  27.0      0  13.0000        S
# 887          888  female  19.0      0  30.0000        S
# 888          889  female   NaN      1  23.4500        S
# 889          890    male  26.0      0  30.0000        C
# 890          891    male  32.0      0   7.7500        Q
#
# [891 rows x 6 columns]

# %%
y_train
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
# Preprocessing and model
scaler = StandardScaler()
model = LogisticRegression()

# Combine preprocessing and model into a pipeline
pipeline = Pipeline(steps=[
    ('scaling', scaler),
    ('logistic_regression', model)
])

# Fit the pipeline on the training data
pipeline.fit(X_train, y_train)

print("Pipeline training complete.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2196\3968666526.py in ?()
#       8     ('logistic_regression', model)
#       9 ])
#      10
#      11 # Fit the pipeline on the training data
# ---> 12 pipeline.fit(X_train, y_train)
#      13
#      14 print("Pipeline training complete.")
#
# ~\anaconda3\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1385                 skip_parameter_validation=(
#    1386                     prefer_skip_nested_validation or global_skip_validation
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#
# ~\anaconda3\Lib\site-packages\sklearn\pipeline.py in ?(self, X, y, **params)
#     648                 "`sklearn.set_config(enable_metadata_routing=True)`."
#     649             )
#     650
# ...
